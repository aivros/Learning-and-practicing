# %% [markdown]
# # 数据分析师

# %% [markdown]
# -------------------     ----------------------------
# - 姓名：                       郭海永
#
# - 电话：                       15220209957
#
# - 微信：                       A0000I
#
# - 邮箱：                        aivros@outlook.com
#
# - 简介：                        https://profiles.udacity.com/p/10905094010
#
# - Github:                      https://github.com/aivros
#
# - Kaggle:                      https://www.kaggle.com/hiyong
#
# - linkdin                      https://www.linkedin.com/in/aivros
# -------------------     ----------------------------
#
#
# 个人擅长：
# ----------
#
# - **以python为主要分析工具，对结构化（SQL等）或非结构化（爬虫）数据进行数据分析流程**
#
# * 可视化展示
#
# * A/B 测试
#
# * 一部分数据分析师工作涉及到的机器学习和深度学习工具

# %% [markdown]
# ### 项目经验：
# ####  是什么影响了电影票房？（IMDB 数据分析）
# - 使用IMDB的规范数据，对电影票房收益率（票房/投入）进行了简要分析。
# - pandas，numpy，seaborn，matplotlib
# - Date：June 2018
# - Link: https://github.com/aivros/Learning-and-practicing/blob/master/Investigate_a_Dataset_aivros.ipynb
#
# #### A/B测试
# - 电子商务网站页面A/B测试分析
# - pandas，numpy，statsmodels，回归分析
# - Date: July 2018
# - Link: https://github.com/aivros/Learning-and-practicing/blob/master/analyze-ab-test-results-notebook-aivros.ipynb
#
# #### CSV查询程序
# - 当前目录读取任意CSV文件，对其作基本处理，规范化，建立索引，查询以及可视化输出。
# - pandas，matplotlib
# - Date: August 2018
# - Link: https://github.com/aivros/Learning-and-practicing/blob/master/csv_qgs_version_1.2.1.py
#
# #### 数据分析工作流（完善中）
#
# - 数据获取-数据存储-数据规范化-数据分析-模型调试-交流展示
# - python
# - Date: November 2018
# - Link:
#
# #### 手写神经网络（NN）
# - 构建最简单的单层神经网络，设置前向传播，反向传播。
# - pandas，numpy
# - Date: November 2018
# - Link:
#
# #### 微信情感分析（NLP）
#
# - 微信朋友圈个性签名分析
# - python
# - Date: October 2018
# - Link:
#
# #### 狗狗分类器（ML）
# - 基于机器学习的分类算法
# - sklearn
# - Date: September 2018
# - Link:
#
# #### 狗狗分类器（DL）
# - 基于神经网络的分类算法
# - tensorflow
# - Date：December 2018
# - Link:

# %% [markdown]
# ### 技能：
# - Programming languages
#     - Python (advanced)
#     - SQL (moderate)
# - Libraries
#     - Python
#         - Numpy
#         - Pandas
#         - Sklearn
#         - TensorFlow
#         - Matplotlib
#         - Scipy
#         - Anaconda
#         - Beautiful Soup
#         - Seaborn
#         - Sequests
#         - Scrapy
# - IDEs
#     - VS code
#     - Jupyter Notebook
#     - Terminal
# - Version Control Systems
#     - Git / GitHub
# - Databases
#     - SQL
# - Data formats
#     - CSV
#     - JSON
#     - SQL databases
#     - Web
# - Operating Systems
#     - Windows 7/8/8.1/10
#     - Ubuntu 16.04
# - Applicable Software
#     - Microsoft Office (Word, Excel, PowerPoint, Outlook, Access, OneNote, SharePoint)
# - Soft skills
#     - Self-taught everything, can learn anything quickly
#     - Easy to get along with, friendly

# %% [markdown]
# ### 教育培训：
# - College/University: None
# - Nanodegrees
#     - Data Analyst Nanodegree
#     - Machine Learning: Course in progress
#     - Deep learning: Course in progress
# - Courses Taken
#     - Udacity
#         - Intro to Computer Science
#         - Intro to Statistics
#         - Intro to Descriptive Statistics
#         - Intro to Inferential Statistics
#         - Intro to Data Science
#         - Data Wrangling with SQL
#         - Data Analysis with python
#         - Intro to Machine Learning
#         - Data Visualization
#         - A/B Testing
#         - Model Evaluation and Validation
#         - Machine Learning: Supervised Learning
#         - Machine Learning: Unsupervised Learning
#         - Machine Learning: Reinforcement Learning
#         - Reinforcement Learning
#         - Deep Learning
#         - Artificial Intelligence for Robotics
#         - Intro to Computer Vision
#         - Machine Learning for Trading
#         - OpenCV
#         - NLP
#     - Khan Academy
#         - Differential Calculus
#         - Integral Calculus
#         - Multivariable Calculus
#         - Linear Algebra
#         - Differential Equations
#     - edX
#         - LFS103x Introduction to Apache Hadoop
#     - Other
#         - MIT 18.06 Linear Algebra
#         - MIT Gilbert Strang：Calculus
#         - Stanford CS231N
#         - Andrew Ng: Machine Learning

# %% [markdown]
# ### 兴趣爱好：
# - 游戏
#     - RPG 仙剑奇侠传4 上古卷轴5
# - 运动
#     - 瑜伽 冥想 娱乐
# - 音乐
#     - 电子乐 Owl city
# - 其它
#     - 科幻 黑科技

# %% [markdown]
# ### 语言能力：
# - English
#     - Reading literature
